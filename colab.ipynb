# %% [markdown]
# # Mount Google Drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %cd "/content/drive/MyDrive/ADL-P01-01/dataset"
# !unzip dataset.zip
# Out:
# /content/drive/MyDrive/ADL-P01-01/dataset

# %% [markdown]
# # Move Classification Data to the Local of CoLab

# %%
# !unzip "/content/drive/MyDrive/ADL-P01-01/dataset/dataset.zip" -d "/content"
# !cp "/content/drive/MyDrive/ADL-P01-01/dataset/dataset/classification/train.csv" "/content/dataset/classification/train.csv"
# !cp "/content/drive/MyDrive/ADL-P01-01/dataset/dataset/classification/test.csv" "/content/dataset/classification/test.csv"
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: /content/dataset/verification/dev/2b420b6aa8.jpg
#   inflating: /content/dataset/verification/dev/2b56a7ba9b.jpg
#   inflating: /content/dataset/verification/dev/2b5d2bf471.jpg
#   inflating: /content/dataset/verification/dev/2b5dccb29b.jpg
#   inflating: /content/dataset/verification/dev/2b65f45add.jpg
#   inflating: /content/dataset/verification/dev/2b674e5c5b.jpg
#   inflating: /content/dataset/verification/dev/2b6a9e8dc3.jpg
#   inflating: /content/dataset/verification/dev/2b70933d85.jpg
#   inflating: /content/dataset/verification/dev/2b8e1a096d.jpg
#   inflating: /content/dataset/verification/dev/2b9431a4e6.jpg
#   inflating: /content/dataset/verification/dev/2bab23a5b8.jpg
#   inflating: /content/dataset/verification/dev/2bae616a31.jpg
#   inflating: /content/dataset/verification/dev/2bd411f0c9.jpg
#   inflating: /content/dataset/verification/dev/2be2e10af4.jpg
# ...

# %% [markdown]
# # Training Face Classifier

# %%
# %cd "/content/drive/MyDrive/ADL-P01-01/"
#!bash ./train.sh
# Out:
# /content/drive/MyDrive/ADL-P01-01
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:481: UserWarning: This DataLoader will create 3 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# Training @ Epoch 0: 100% 625/625 [00:50<00:00, 12.27batch/s, accuracy=000%, loss=22.249]
# Validation @ Epoch  0: 100% 157/157 [00:06<00:00, 23.32batch/s, accuracy=000, loss=22.134]
# Training @ Epoch 1: 100% 625/625 [00:51<00:00, 12.07batch/s, accuracy=000%, loss=21.406]
# Validation @ Epoch  1: 100% 157/157 [00:06<00:00, 23.56batch/s, accuracy=000, loss=20.585]
# Training @ Epoch 2: 100% 625/625 [00:51<00:00, 12.24batch/s, accuracy=000%, loss=20.810]
# ...

# %% [markdown]
# # Move Validation Data to the Local of CoLab

# %%
# !unzip "/content/drive/MyDrive/ADL-P01-01/dataset/dataset.zip" -d "/content"
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: /content/dataset/verification/dev/2b420b6aa8.jpg
#   inflating: /content/dataset/verification/dev/2b56a7ba9b.jpg
#   inflating: /content/dataset/verification/dev/2b5d2bf471.jpg
#   inflating: /content/dataset/verification/dev/2b5dccb29b.jpg
#   inflating: /content/dataset/verification/dev/2b65f45add.jpg
#   inflating: /content/dataset/verification/dev/2b674e5c5b.jpg
#   inflating: /content/dataset/verification/dev/2b6a9e8dc3.jpg
#   inflating: /content/dataset/verification/dev/2b70933d85.jpg
#   inflating: /content/dataset/verification/dev/2b8e1a096d.jpg
#   inflating: /content/dataset/verification/dev/2b9431a4e6.jpg
#   inflating: /content/dataset/verification/dev/2bab23a5b8.jpg
#   inflating: /content/dataset/verification/dev/2bae616a31.jpg
#   inflating: /content/dataset/verification/dev/2bd411f0c9.jpg
#   inflating: /content/dataset/verification/dev/2be2e10af4.jpg
# ...

# %% [markdown]
# # Face Verification

# %%
# %cd "/content/drive/MyDrive/ADL-P01-01/"
# !bash ./verification.sh
# Out:
# /content/drive/MyDrive/ADL-P01-01
# Downloading: "https://download.pytorch.org/models/resnet50-0676ba61.pth" to /root/.cache/torch/hub/checkpoints/resnet50-0676ba61.pth
# 100% 97.8M/97.8M [00:01<00:00, 56.8MB/s]
# Loading the model from './checkpoints_resnet50/ckpt__final'
# Verfication: 100% 2607/2607 [10:12<00:00,  4.26batch/s]
#
# Report file is saving ('./reports/verification_resnet50_2022_4_6_20_32_58.csv')....
